# %%
import pandas as pd
import matplotlib.pyplot as plt
import folium
import plotly.express as px

# Plot inline
# %matplotlib inline

# %%
df = pd.read_parquet("../processed_data/00000001.parquet")
df.head()
# Out:
#    timestamps  CAN_DataFrame.CAN_DataFrame.BusChannel  \
# 0        0.00                                       1
# 1        0.01                                       2
# 2        0.01                                       1
# 3        0.02                                       1
# 4        0.03                                       1
#
#    CAN_DataFrame.CAN_DataFrame.ID  CAN_DataFrame.CAN_DataFrame.IDE  \
# 0                       217056257                                1
# 1                            2015                                0
# 2                       217056257                                1
# 3                       217056257                                1
# 4                       217056257                                1
#
#    CAN_DataFrame.CAN_DataFrame.DLC  CAN_DataFrame.CAN_DataFrame.DataLength  \
# 0                                8                                       8
# 1                                8                                       8
# ...

# %%
df.columns.tolist()
# Out:
# ['timestamps',
#  'CAN_DataFrame.CAN_DataFrame.BusChannel',
#  'CAN_DataFrame.CAN_DataFrame.ID',
#  'CAN_DataFrame.CAN_DataFrame.IDE',
#  'CAN_DataFrame.CAN_DataFrame.DLC',
#  'CAN_DataFrame.CAN_DataFrame.DataLength',
#  'CAN_DataFrame.CAN_DataFrame.DataBytes',
#  'CAN_DataFrame.CAN_DataFrame.Dir',
#  'CAN_DataFrame.CAN_DataFrame.EDL',
#  'CAN_DataFrame.CAN_DataFrame.BRS',
#  'Time']
