# %%
import pandas as pd
from pathlib import Path

# Load data
csv_path = Path("../relevant_signals_obd.csv")  # Adjust if needed
df_signals = pd.read_csv(csv_path)

print("✅ Loaded signals:")
df_signals.head(20)
# Out:
# ✅ Loaded signals:
#    CAN_Channel  CAN_ID            CAN_Name                Signal  \
# 0         CAN1     NaN     ID108DIR_torque         DIR_axleSpeed
# 1         CAN1     NaN  ID129SteeringAngle      SteeringAngle129
# 2         CAN9     NaN            GnssTime                 Epoch
# 3         CAN9     NaN             GnssPos             Longitude
# 4         CAN9     NaN           GnssSpeed                 Speed
# 5         CAN9     NaN             GnssPos              Latitude
# 6         CAN1     NaN     ID1D8RearTorque  RearTorqueRequest1D8
# 7         CAN1     NaN     ID1D8RearTorque         RearTorque1D8
# 8         CAN1     NaN        ID257DIspeed       DI_vehicleSpeed
# 9         CAN1     NaN     ID108DIR_torque      DIR_torqueActual
# 10        CAN1     NaN     ID108DIR_torque     DIR_torqueCommand
# 11        CAN1     NaN  ID129SteeringAngle      SteeringSpeed129
# 12        CAN9     NaN        GnssAltitude              Altitude
# ...

# %%
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 df.signals()
#
# NameError: name 'df' is not defined
